# %% [markdown]
# # Argentina Happiness Report
# On this notebook I will be working with the Wold Happiness Report 2021. This job was inspired by https://www.kaggle.com/ajaypalsinghlo/world-happiness-report-2021-word, which is focused on India. I will focus this analysis on Argentina and the countries of the Mercosur.
# The World Happiness Report is a publication of the Sustainable Development Solutions Network, powered by data from the Gallup World Poll and Lloyd’s Register Foundation, who provided access to the World Risk Poll.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file="world-happiness-report.csv"
world=pd.read_csv(file)
print(world.columns)
world.head()
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# ...

# %% [markdown]
# On this first dataset we have information back up to 2005. The Happiness Report provides information about 6 topics: GDP per capita, social support, healthy life expectancy, freedom to make life choices, generoristy and perception of corruption. Let's focus on Argentina and let's see how all the variables changed through the years.

# %%
argentina=world[world['Country name']=='Argentina']
argentina
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 37    Argentina  2006        6.313               9.942           0.938
# 38    Argentina  2007        6.073              10.018           0.862
# 39    Argentina  2008        5.961              10.048           0.892
# 40    Argentina  2009        6.424               9.977           0.919
# 41    Argentina  2010        6.441              10.066           0.927
# 42    Argentina  2011        6.776              10.112           0.889
# 43    Argentina  2012        6.468              10.091           0.902
# 44    Argentina  2013        6.582              10.103           0.910
# 45    Argentina  2014        6.671              10.067           0.918
# 46    Argentina  2015        6.697              10.083           0.926
# 47    Argentina  2016        6.427              10.051           0.883
# 48    Argentina  2017        6.039              10.067           0.907
# ...

# %%
plt.figure(figsize=(25,8))
sns.lineplot(data=argentina, x="year", y="Life Ladder", markers=True)
plt.title('Life Ladder', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Life Ladder')

# %%
plt.figure(figsize=(25,8))
sns.lineplot(data=argentina, x='year', y='Log GDP per capita')
plt.title('Logged GDP per capita', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Logged GDP per capita')

# %%
plt.figure(figsize=(25,8))
sns.lineplot(data=argentina, x='year', y='Social support')
plt.title('Social Support', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Social Support')

# %%
plt.figure(figsize=(25,8))
sns.lineplot(data=argentina, x='year', y='Healthy life expectancy at birth')
plt.title('Healthy Life Expectancy at birth', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Healthy Life Expectancy at birth')

# %%
plt.figure(figsize=(25,8))
sns.lineplot(data=argentina, x='year', y='Freedom to make life choices')
plt.title('Freedom to make life choices', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Freedom to make life choices')

# %%
plt.figure(figsize=(25,8))
sns.lineplot(data=argentina, x='year', y='Generosity')
plt.title('Generosity', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Generosity')

# %%
plt.figure(figsize=(25,8))
sns.lineplot(data=argentina, x='year', y='Perceptions of corruption')
plt.title('Percepcions of Corruption', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Percepcions of Corruption')

# %% [markdown]
# Now we'll work with a second dataset which contains data about the report made for 2021.

# %%
report_2021=pd.read_csv('world-happiness-report-2021.csv')
print(report_2021.head())
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %% [markdown]
# Let's now focus on the countries that are part ot the Mercosur.
# The Mercosur (Mercado Común del Sur or Southern Common Market) is a trade bloc founded in 1991. Its full members are Argentina, Brazil, Paraguay, Uruguay and Venezuela (suspended since 2016). Its associated members are Chile, Bolivia, Colombia, Ecuador, Perú, Surinam and Guyana.
# Sadly the report doesn't have data about Surinam and Guyana so they will not be considered here.

# %%
mercosur=report_2021[(report_2021['Country name']=='Argentina') | (report_2021['Country name']=='Uruguay') | (report_2021['Country name']=='Brazil') | (report_2021['Country name']=='Paraguay') | (report_2021['Country name']=='Venezuela') | (report_2021['Country name']=='Chile') | (report_2021['Country name']=='Bolivia') | (report_2021['Country name']=='Colombia') | (report_2021['Country name']=='Peru') | (report_2021['Country name']=='Ecuador')]
mercosur
# Out:
#     Country name           Regional indicator  Ladder score  \
# 30       Uruguay  Latin America and Caribbean         6.431
# 34        Brazil  Latin America and Caribbean         6.330
# 42         Chile  Latin America and Caribbean         6.172
# 51      Colombia  Latin America and Caribbean         6.012
# 56     Argentina  Latin America and Caribbean         5.929
# 62          Peru  Latin America and Caribbean         5.840
# 65       Ecuador  Latin America and Caribbean         5.764
# 68       Bolivia  Latin America and Caribbean         5.716
# 70      Paraguay  Latin America and Caribbean         5.653
# 106    Venezuela  Latin America and Caribbean         4.892
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 30                            0.046         6.521         6.341
# 34                            0.043         6.415         6.245
# 42                            0.046         6.262         6.081
# ...

# %%
plt.figure(figsize=(25, 8))
plt.title('Comparison of Ladder Scores in Mercosur countries', fontsize=24)
sns.barplot(data=mercosur, x='Country name', y='Ladder score')
# Out:
# <AxesSubplot:title={'center':'Comparison of Ladder Scores in Mercosur countries'}, xlabel='Country name', ylabel='Ladder score'>

# %%
plt.figure(figsize=(25, 8))
plt.title('Comparison of Logged GDP per capita in Mercosur countries', fontsize=24)
sns.barplot(data=mercosur, x='Country name', y='Logged GDP per capita')
# Out:
# <AxesSubplot:title={'center':'Comparison of Logged GDP per capita in Mercosur countries'}, xlabel='Country name', ylabel='Logged GDP per capita'>

# %%
plt.figure(figsize=(25, 8))
plt.title('Comparison of Social Support in Mercosur countries', fontsize=24)
sns.barplot(data=mercosur, x='Country name', y='Social support')
# Out:
# <AxesSubplot:title={'center':'Comparison of Social Support in Mercosur countries'}, xlabel='Country name', ylabel='Social support'>

# %%
plt.figure(figsize=(25, 8))
plt.title('Comparison of Health Life Expectancy in Mercosur countries', fontsize=24)
sns.barplot(data=mercosur, x='Country name', y='Healthy life expectancy')
# Out:
# <AxesSubplot:title={'center':'Comparison of Health Life Expectancy in Mercosur countries'}, xlabel='Country name', ylabel='Healthy life expectancy'>

# %%
plt.figure(figsize=(25, 8))
plt.title('Comparison of freedom to make life choices in Mercosur countries', fontsize=24)
sns.barplot(data=mercosur, x='Country name', y='Freedom to make life choices')
# Out:
# <AxesSubplot:title={'center':'Comparison of freedom to make life choices in Mercosur countries'}, xlabel='Country name', ylabel='Freedom to make life choices'>

# %%
plt.figure(figsize=(25, 8))
plt.title('Comparison of generosity in Mercosur countries', fontsize=24)
sns.barplot(data=mercosur, x='Country name', y='Generosity')
# Out:
# <AxesSubplot:title={'center':'Comparison of generosity in Mercosur countries'}, xlabel='Country name', ylabel='Generosity'>

# %%
plt.figure(figsize=(25, 8))
plt.title('Comparison of Perceptions of Corruption in Mercosur countries', fontsize=24)
sns.barplot(data=mercosur, x='Country name', y='Perceptions of corruption')
# Out:
# <AxesSubplot:title={'center':'Comparison of Perceptions of Corruption in Mercosur countries'}, xlabel='Country name', ylabel='Perceptions of corruption'>
